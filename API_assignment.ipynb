# %% [markdown]
# <a href="https://colab.research.google.com/github/Gtebaldi1/HHA504_Practice/blob/main/API_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Installing needed packages ***

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# **Writing a get request to pull data from API: CoronaVirus data in the UK**

# %%
response= requests.get('https://api.coronavirus.data.gov.uk/v1/data')

# %%
jsonresponse.status_code
# Out:
# 200

# %% [markdown]
# **Retrieving the data**

# %%
response.json()
# Out:
# {'data': [{'casesCumulative': 8231437,
#    'casesDaily': 38520,
#    'date': '2021-10-12',
#    'deathsCumulative': 137944,
#    'deathsDaily': 181,
#    'firstVaccinationsCumulative': None,
#    'firstVaccinationsDaily': None,
#    'name': 'United Kingdom',
#    'newHospitalisations': None,
#    'secondVaccinationsCumulative': None,
#    'secondVaccinationsDaily': None},
#   {'casesCumulative': 8193769,
#    'casesDaily': 40224,
#    'date': '2021-10-11',
#    'deathsCumulative': 137763,
#    'deathsDaily': 28,
#    'firstVaccinationsCumulative': 49216092,
#    'firstVaccinationsDaily': 29172,
#    'name': 'United Kingdom',
#    'newHospitalisations': None,
#    'secondVaccinationsCumulative': 45212813,
#    'secondVaccinationsDaily': 23632},
#   {'casesCumulative': 8154306,
#    'casesDaily': 34574,
#    'date': '2021-10-10',
#    'deathsCumulative': 137735,
#    'deathsDaily': 38,
#    'firstVaccinationsCumulative': 49186920,
#    'firstVaccinationsDaily': 22106,
# ...
